# %%
import chromedriver_autoinstaller
from selenium import webdriver
from bs4 import BeautifulSoup

chromedriver_autoinstaller.install() # chromedriver 최신버전설치
browser = webdriver.Chrome()    # 브라우저 열기

# %%
browser.close()

# %%
url = 'https://daum.net'
browser.get(url)

# %%
https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%ED%8C%8C%EC%9D%B4%EC%8D%AC

# %% [markdown]
# URL
# - 주소 : naver.com www.google.com
#     ?
# - 파라미터 : 변수=값 & 변수2=값2 & 변수3=값3

# %%
word_list = ['모두의연구소','파이썬','부동산','주식','해외주식','데이터분석']
for word in word_list:
    url = f'https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q={word}'
    print(url)
    browser.get(url)
    # 크롤링 코드...
# Out:
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=모두의연구소
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=파이썬
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=부동산
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=주식
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=해외주식
# https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=데이터분석

# %% [markdown]
# # 다음뉴스 페이지 크롤링하기

# %%
url = 'https://news.v.daum.net/v/20160310190303578'
browser.get(url)

# %%
# browser.page_source
soup = BeautifulSoup(browser.page_source, 'html.parser' )

# %%
soup
# Out:
# <html lang="ko"><head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/ad23f0c9e6dfe91eebd21c5a9bf5fb189c454f1c1648095650663.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2022/03/24/common.ad2410f730e5fb126f3d.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="JDxuFRaEbq" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content='이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"' property="og:title"/>
# <meta content="20160310190302" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="오마이뉴스" property="og:article:author"/>
# <meta content="https://news.v.daum.net/v/JDxuFRaEbq" property="og:url"/>
# ...

# %% [markdown]
# 1. 브라우저 열기
# 2. 웹페이지 접속하기
# 3. 정보 있는지 확인하기
# 4. 데이터 다운 및 해석하기
# 5. 데이터 찾기

# %%
# soup.select('조건')

# %% [markdown]
# 1.<tag> </tag>
#    <span> </span>
# 2.<tag>파이썬</tag>
# 3.<tag명 속성=값> </tag명>
#    <tag명 속성=값 속성2=값2 속성3=값3> </tag명>
#    <h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>
#    <tag명 class='값' id='값2'>
# 4.
# <tag1>
#     <tag2> </tag2>
#     <tag3>
#         <tag4>Lee</tag4>
#     </tag3>
# </tag1>

# %%
soup
# Out:
# <html lang="ko"><head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/ad23f0c9e6dfe91eebd21c5a9bf5fb189c454f1c1648095650663.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2022/03/24/common.ad2410f730e5fb126f3d.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="JDxuFRaEbq" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content='이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"' property="og:title"/>
# <meta content="20160310190302" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="오마이뉴스" property="og:article:author"/>
# <meta content="https://news.v.daum.net/v/JDxuFRaEbq" property="og:url"/>
# ...

# %%
soup.select('h3')
len(soup.select('h3'))
# Out:
# 4

# %%
soup.select('h3.tit_view')
# Out:
# [<h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>]

# %%
title = soup.select('h3')
len(title)
# Out:
# 4

# %%
soup.select('h3')[0]
# Out:
# <h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>

# %%
soup.select('h3')[1]
# Out:
# <h3 class="tit_cp">오마이뉴스 주요 뉴스</h3>

# %%
title = soup.select('h3')[0].text

# %%
title
# Out:
# '이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"'

# %%
# soup.select('부모태그 > 자식태그')
soup.select('div > h3.tit_view')  # div 태그 바로 아래 h3.tit_view찾기
# Out:
# [<h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>]

# %%
soup.select('.head_view > h3.tit_view')
# Out:
# [<h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>]

# %%
soup.select('#cSub > div > h3.tit_view')  # id속성값이 cSub 인 태그 다 찾아줘
# Out:
# [<h3 class="tit_view" data-translation="true">이세돌 "알파고의 완승, 완벽한 대국 펼쳤다"</h3>]

# %%
<img src="https://t1.daumcdn.net/media/news/news2016/cp/cp_ohmynews.gif" class="thumb_g" alt="오마이뉴스">

# %%
# 오마이뉴스 찾기
press = soup.select('a.link_cp > img.thumb_g')[0]['alt']
press
# Out:
# '오마이뉴스'

# %% [markdown]
# 1.브라우저 열기
# 2.접속하기
# 3.정보 확인
#     * 정보가 나타나도록 브라우저 조작 : 클릭/입력/삭제
# 4.데이터 다운 & 해석
# 5.정보 찾기
#     5-1. 태그 찾기
#         soup.select('태그조건')
#             .select('태그명')
#                 '.class속성값'
#                 '#id속성값'
#                 '부모태그조건 > 자식태그조건'
#     5-2
#         tag.txt 화면에 보이는 글
#         tag['속성명']
# 6.엑셀 저장하기
